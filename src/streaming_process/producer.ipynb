# %%
from kafka import KafkaProducer
import json
import time

# Initialize Kafka producer
producer = KafkaProducer(
    bootstrap_servers='localhost:9092',
    value_serializer=lambda v: json.dumps(v).encode('utf-8')
)

# %%
import pandas as pd 
loan_application = pd.read_csv("/home/drissdo/Desktop/Scalable-Distributed-Systems/data/Loan_default.csv")

# %%
loan_applications = loan_application.sample(32)[:20].drop(["Default"],axis=1)

# %%
loan_applications
# Out:
#             LoanID  Age  Income  LoanAmount  CreditScore  MonthsEmployed  \
# 17210   LR72FBE9QZ   32  143785      226440          727              67
# 228890  F9RI2LE7RS   33  124309       72341          369              39
# 52700   T7OUH9ZDVD   66  135437      117097          753              90
# 19320   7QKAMOXYGH   29   43545      188700          454             105
# 221740  Y6CM0E9DWU   18   20511      218155          306              18
# 139446  UVBV4LRQNR   50   28789       50646          741              19
# 195089  RVE5YZ2MMB   40   72283       64835          347              51
# 215051  KUQYPAAJGU   38   86076       80358          641              38
# 95753   P1DNQAJ431   37  129689      117869          810              93
# 225716  WQHER4W9FN   31  120560      149027          829             112
# 111225  JI97CW7034   63   79279       76261          744             106
# 215090  J7HB3OZRFF   52   52217       10683          697              73
# 127965  DNY2M3N3YP   67  137154      160160          545              52
# 101996  KC0IM9I842   46   90284       26396          761              67
# 129677  P8JY7P417L   62   63004       55712          690              74
# 81470   BZ6MYUBUY2   54   95325      225815          845             102
# 117896  XFTBE3BYO5   67   54959       67603          782              40
# 135965  B46N8F3V4R   28   96239       23118          731             109
# 234340  ZR4QCQ9V92   33   36596      208997          679              14
# 214746  QKVUR65HAY   29   37939      157020          752              15
#
#         NumCreditLines  InterestRate  LoanTerm  DTIRatio    Education  \
# 17210                3          3.06        60      0.16   Bachelor's
# 228890               4         23.06        12      0.62     Master's
# 52700                3         16.43        36      0.17     Master's
# 19320                3         22.38        24      0.13   Bachelor's
# 221740               1         11.10        36      0.31  High School
# 139446               4          5.11        12      0.66  High School
# 195089               2         21.13        24      0.73     Master's
# 215051               2         12.04        60      0.56  High School
# 95753                3         19.65        48      0.72          PhD
# 225716               4          5.32        24      0.51   Bachelor's
# 111225               4          8.74        48      0.68  High School
# 215090               1          5.69        36      0.90     Master's
# 127965               1         24.25        48      0.88  High School
# 101996               2         22.07        12      0.55   Bachelor's
# 129677               4         17.89        36      0.41     Master's
# 81470                2         24.92        48      0.76          PhD
# 117896               2         15.19        36      0.12  High School
# 135965               3          6.00        48      0.55   Bachelor's
# 234340               2         11.13        24      0.54          PhD
# 214746               4         19.71        48      0.15  High School
#
#        EmploymentType MaritalStatus HasMortgage HasDependents LoanPurpose  \
# 17210       Full-time      Divorced          No            No    Business
# 228890  Self-employed      Divorced          No           Yes       Other
# 52700       Part-time       Married          No           Yes    Business
# 19320       Part-time       Married         Yes            No    Business
# 221740     Unemployed      Divorced          No           Yes        Home
# 139446      Part-time        Single         Yes            No    Business
# 195089      Part-time        Single         Yes            No        Home
# 215051      Part-time       Married          No           Yes    Business
# 95753       Part-time      Divorced          No           Yes        Auto
# 225716      Full-time        Single          No           Yes    Business
# 111225  Self-employed       Married          No            No        Home
# 215090      Full-time      Divorced         Yes            No        Auto
# 127965      Part-time      Divorced         Yes            No        Auto
# 101996     Unemployed       Married          No            No       Other
# 129677      Full-time      Divorced          No            No       Other
# 81470      Unemployed        Single          No            No       Other
# 117896  Self-employed      Divorced         Yes           Yes        Auto
# 135965      Full-time        Single         Yes            No        Auto
# 234340      Part-time       Married          No            No   Education
# 214746     Unemployed      Divorced         Yes           Yes        Auto
#
#        HasCoSigner
# 17210           No
# 228890          No
# 52700          Yes
# 19320          Yes
# 221740          No
# 139446         Yes
# 195089         Yes
# 215051          No
# 95753          Yes
# 225716          No
# 111225         Yes
# 215090         Yes
# 127965         Yes
# 101996         Yes
# 129677          No
# 81470           No
# 117896          No
# 135965         Yes
# 234340          No
# 214746          No

# %%
topic ="loan_applications"
for _, row in loan_applications.iterrows():
    message = row.to_dict()  # Convert row to dictionary
    producer.send(topic, value=message)  # Send the message
    print(f"Sent: {message}")
# Out:
# Sent: {'LoanID': 'LR72FBE9QZ', 'Age': 32, 'Income': 143785, 'LoanAmount': 226440, 'CreditScore': 727, 'MonthsEmployed': 67, 'NumCreditLines': 3, 'InterestRate': 3.06, 'LoanTerm': 60, 'DTIRatio': 0.16, 'Education': "Bachelor's", 'EmploymentType': 'Full-time', 'MaritalStatus': 'Divorced', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Business', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'F9RI2LE7RS', 'Age': 33, 'Income': 124309, 'LoanAmount': 72341, 'CreditScore': 369, 'MonthsEmployed': 39, 'NumCreditLines': 4, 'InterestRate': 23.06, 'LoanTerm': 12, 'DTIRatio': 0.62, 'Education': "Master's", 'EmploymentType': 'Self-employed', 'MaritalStatus': 'Divorced', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Other', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'T7OUH9ZDVD', 'Age': 66, 'Income': 135437, 'LoanAmount': 117097, 'CreditScore': 753, 'MonthsEmployed': 90, 'NumCreditLines': 3, 'InterestRate': 16.43, 'LoanTerm': 36, 'DTIRatio': 0.17, 'Education': "Master's", 'EmploymentType': 'Part-time', 'MaritalStatus': 'Married', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Business', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': '7QKAMOXYGH', 'Age': 29, 'Income': 43545, 'LoanAmount': 188700, 'CreditScore': 454, 'MonthsEmployed': 105, 'NumCreditLines': 3, 'InterestRate': 22.38, 'LoanTerm': 24, 'DTIRatio': 0.13, 'Education': "Bachelor's", 'EmploymentType': 'Part-time', 'MaritalStatus': 'Married', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Business', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'Y6CM0E9DWU', 'Age': 18, 'Income': 20511, 'LoanAmount': 218155, 'CreditScore': 306, 'MonthsEmployed': 18, 'NumCreditLines': 1, 'InterestRate': 11.1, 'LoanTerm': 36, 'DTIRatio': 0.31, 'Education': 'High School', 'EmploymentType': 'Unemployed', 'MaritalStatus': 'Divorced', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Home', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'UVBV4LRQNR', 'Age': 50, 'Income': 28789, 'LoanAmount': 50646, 'CreditScore': 741, 'MonthsEmployed': 19, 'NumCreditLines': 4, 'InterestRate': 5.11, 'LoanTerm': 12, 'DTIRatio': 0.66, 'Education': 'High School', 'EmploymentType': 'Part-time', 'MaritalStatus': 'Single', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Business', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'RVE5YZ2MMB', 'Age': 40, 'Income': 72283, 'LoanAmount': 64835, 'CreditScore': 347, 'MonthsEmployed': 51, 'NumCreditLines': 2, 'InterestRate': 21.13, 'LoanTerm': 24, 'DTIRatio': 0.73, 'Education': "Master's", 'EmploymentType': 'Part-time', 'MaritalStatus': 'Single', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Home', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'KUQYPAAJGU', 'Age': 38, 'Income': 86076, 'LoanAmount': 80358, 'CreditScore': 641, 'MonthsEmployed': 38, 'NumCreditLines': 2, 'InterestRate': 12.04, 'LoanTerm': 60, 'DTIRatio': 0.56, 'Education': 'High School', 'EmploymentType': 'Part-time', 'MaritalStatus': 'Married', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Business', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'P1DNQAJ431', 'Age': 37, 'Income': 129689, 'LoanAmount': 117869, 'CreditScore': 810, 'MonthsEmployed': 93, 'NumCreditLines': 3, 'InterestRate': 19.65, 'LoanTerm': 48, 'DTIRatio': 0.72, 'Education': 'PhD', 'EmploymentType': 'Part-time', 'MaritalStatus': 'Divorced', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Auto', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'WQHER4W9FN', 'Age': 31, 'Income': 120560, 'LoanAmount': 149027, 'CreditScore': 829, 'MonthsEmployed': 112, 'NumCreditLines': 4, 'InterestRate': 5.32, 'LoanTerm': 24, 'DTIRatio': 0.51, 'Education': "Bachelor's", 'EmploymentType': 'Full-time', 'MaritalStatus': 'Single', 'HasMortgage': 'No', 'HasDependents': 'Yes', 'LoanPurpose': 'Business', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'JI97CW7034', 'Age': 63, 'Income': 79279, 'LoanAmount': 76261, 'CreditScore': 744, 'MonthsEmployed': 106, 'NumCreditLines': 4, 'InterestRate': 8.74, 'LoanTerm': 48, 'DTIRatio': 0.68, 'Education': 'High School', 'EmploymentType': 'Self-employed', 'MaritalStatus': 'Married', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Home', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'J7HB3OZRFF', 'Age': 52, 'Income': 52217, 'LoanAmount': 10683, 'CreditScore': 697, 'MonthsEmployed': 73, 'NumCreditLines': 1, 'InterestRate': 5.69, 'LoanTerm': 36, 'DTIRatio': 0.9, 'Education': "Master's", 'EmploymentType': 'Full-time', 'MaritalStatus': 'Divorced', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Auto', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'DNY2M3N3YP', 'Age': 67, 'Income': 137154, 'LoanAmount': 160160, 'CreditScore': 545, 'MonthsEmployed': 52, 'NumCreditLines': 1, 'InterestRate': 24.25, 'LoanTerm': 48, 'DTIRatio': 0.88, 'Education': 'High School', 'EmploymentType': 'Part-time', 'MaritalStatus': 'Divorced', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Auto', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'KC0IM9I842', 'Age': 46, 'Income': 90284, 'LoanAmount': 26396, 'CreditScore': 761, 'MonthsEmployed': 67, 'NumCreditLines': 2, 'InterestRate': 22.07, 'LoanTerm': 12, 'DTIRatio': 0.55, 'Education': "Bachelor's", 'EmploymentType': 'Unemployed', 'MaritalStatus': 'Married', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Other', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'P8JY7P417L', 'Age': 62, 'Income': 63004, 'LoanAmount': 55712, 'CreditScore': 690, 'MonthsEmployed': 74, 'NumCreditLines': 4, 'InterestRate': 17.89, 'LoanTerm': 36, 'DTIRatio': 0.41, 'Education': "Master's", 'EmploymentType': 'Full-time', 'MaritalStatus': 'Divorced', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Other', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'BZ6MYUBUY2', 'Age': 54, 'Income': 95325, 'LoanAmount': 225815, 'CreditScore': 845, 'MonthsEmployed': 102, 'NumCreditLines': 2, 'InterestRate': 24.92, 'LoanTerm': 48, 'DTIRatio': 0.76, 'Education': 'PhD', 'EmploymentType': 'Unemployed', 'MaritalStatus': 'Single', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Other', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'XFTBE3BYO5', 'Age': 67, 'Income': 54959, 'LoanAmount': 67603, 'CreditScore': 782, 'MonthsEmployed': 40, 'NumCreditLines': 2, 'InterestRate': 15.19, 'LoanTerm': 36, 'DTIRatio': 0.12, 'Education': 'High School', 'EmploymentType': 'Self-employed', 'MaritalStatus': 'Divorced', 'HasMortgage': 'Yes', 'HasDependents': 'Yes', 'LoanPurpose': 'Auto', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'B46N8F3V4R', 'Age': 28, 'Income': 96239, 'LoanAmount': 23118, 'CreditScore': 731, 'MonthsEmployed': 109, 'NumCreditLines': 3, 'InterestRate': 6.0, 'LoanTerm': 48, 'DTIRatio': 0.55, 'Education': "Bachelor's", 'EmploymentType': 'Full-time', 'MaritalStatus': 'Single', 'HasMortgage': 'Yes', 'HasDependents': 'No', 'LoanPurpose': 'Auto', 'HasCoSigner': 'Yes'}
# Sent: {'LoanID': 'ZR4QCQ9V92', 'Age': 33, 'Income': 36596, 'LoanAmount': 208997, 'CreditScore': 679, 'MonthsEmployed': 14, 'NumCreditLines': 2, 'InterestRate': 11.13, 'LoanTerm': 24, 'DTIRatio': 0.54, 'Education': 'PhD', 'EmploymentType': 'Part-time', 'MaritalStatus': 'Married', 'HasMortgage': 'No', 'HasDependents': 'No', 'LoanPurpose': 'Education', 'HasCoSigner': 'No'}
# Sent: {'LoanID': 'QKVUR65HAY', 'Age': 29, 'Income': 37939, 'LoanAmount': 157020, 'CreditScore': 752, 'MonthsEmployed': 15, 'NumCreditLines': 4, 'InterestRate': 19.71, 'LoanTerm': 48, 'DTIRatio': 0.15, 'Education': 'High School', 'EmploymentType': 'Unemployed', 'MaritalStatus': 'Divorced', 'HasMortgage': 'Yes', 'HasDependents': 'Yes', 'LoanPurpose': 'Auto', 'HasCoSigner': 'No'}

# %%
producer.close()
